# %% [markdown]
# ```python
# import os
#
# for foldername, subfolders,filenames in os.walk('.'):
#     print('-'*20)
#     print(foldername)
#     print('-'*20)
#
#
#     print(subfolders)
#     print('-'*20)
#
#     print(filenames)
#     print('^'*50)
# ```

# %%
import os

for foldername, subfolders,filenames in os.walk('.'):
    print('-'*20)
    print(foldername)
    print('-'*20)

   
    print(subfolders)
    print('-'*20)

    print(filenames)
    print('^'*50)
# Out:
# --------------------
# .
# --------------------
# ['os.walk_test', '.jupyter', '数据结构与算法', 'jupyter-notebook', 'spring-framework', '数据分析', 'easygui', '.pycharm_helpers', 'scrapy20', '.cache', 'django18', 'data', 'dailyfresh', '07_语法进阶', 'pyreview', '.ssh', '.vim', '.ipython', 'redis', 'flask19', '前端练习代码', '.virtualenvs', '.nano', '.local', '.oracle_jre_usage', '快速相关攻击', 'ml', '后端学习代码', 'spider20', '.config', '天天生鲜', '.git']
# --------------------
# ['.gitconfig', '.python_history', '.bash_history', '.profile', '.viminfo', '.mysql_history', 'jupyter_notebook_config.py', 'data1.txt', '.bashrc']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# --------------------
# ./os.walk_test
# --------------------
# ['第一层文件夹1', '第一层文件夹0']
# --------------------
# ['oswalk_test.py']
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# --------------------
# ./os.walk_test/第一层文件夹1
# --------------------
# ['第二层文件夹1']
# --------------------
# []
# ...
