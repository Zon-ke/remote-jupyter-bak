# %%
#coding=utf-8
log_dict = {}
file_path = './jupyter-notebook/jupyter.log'
with open(file_path,'r')as f:
    for line in f:
        a = ['nohup: ignoring input\n']
        if len(line) > len(a)+2:
#             print(line.split('['))
            line = line.split('[')
#             print(type(line))
#             print("len:",len(line))
            if len(line) > 1:
#                 print(type(line[1]))
                line_str = line[1]
#                 print("line_str:",line_str[1])
                line_str_list = line_str.split(']')
#                 print(line_str_list)
#                 log_dict[line_str_list[0]] = line_str_list[1]
#                 print([i for i in log_dict])
                line_str_list_spl = line_str_list[0].split(' ')
                new_line_str_list_spl = line_str_list_spl+line_str_list[1:]

print()
# Out:
# {'I 17:35:37.470 NotebookApp': ' Saving file at /Bit_Attack.ipynb\n', 'I 12:04:01.920 NotebookApp': ' Saving file at /json_process/查找json文件并读取.ipynb\n', 'W 11:41:52.925 NotebookApp': ' IOPub data rate exceeded.\n', 'W 12:21:02.211 NotebookApp': ' 403 POST /api/kernels (223.65.190.2) 0.94ms referer=None\n', 'I 22:30:44.068 NotebookApp': ' Adapting to protocol v5.1 for kernel 79f6dec2-32f3-474b-b671-35da9f459277\n', 'I 12:21:17.230 NotebookApp': ' 302 GET /tree? (223.65.190.2) 0.64ms\n', 'I 01:59:16.985 NotebookApp': ' Adapting to protocol v5.1 for kernel 79f6dec2-32f3-474b-b671-35da9f459277\n', 'I 15:52:50.620 NotebookApp': ' Starting buffering for 79f6dec2-32f3-474b-b671-35da9f459277:98e0e3f0a6204bb79144f0726ab26718\n', 'I 16:24:28.787 NotebookApp': ' Saving file at /json_process/Untitled.ipynb\n', 'I 11:42:23.552 NotebookApp': ' Saving file at /test_night.ipynb\n', 'W 13:02:14.495 NotebookApp': ' 404 GET /public/index.php?s=index/think\\app/invokefunction&function=call_user_func_arr
# ...

# %%
import pandas as pd
import numpy as np

# %%
line = '[I 12:16:29.052 NotebookApp] Serving notebooks from local directory: /root/jupyter-notebook'

# %%
line1 = line.split("[")

# %%
line2 = line1[1]

# %%
line3 = line2.split(']')

# %%
line3
# Out:
# ['I 12:16:29.052 NotebookApp',
#  ' Serving notebooks from local directory: /root/jupyter-notebook']

# %%
line3_spl = line3[0].split(' ')
line3_str = line3[1]

# %%
line3_str
# Out:
# ' Serving notebooks from local directory: /root/jupyter-notebook'

# %%
line3_spl
# Out:
# ['I', '12:16:29.052', 'NotebookApp']

# %%
new_line3 = line3_spl+line3[1:]

# %%
new_line3
# Out:
# ['I',
#  '12:16:29.052',
#  'NotebookApp',
#  ' Serving notebooks from local directory: /root/jupyter-notebook']

# %%
df_new_line3 = pd.DataFrame(new_line3)

# %%
df_new_line3
# Out:
# 0                                                    I
# 1                                         12:16:29.052
# 2                                          NotebookApp
# 3     Serving notebooks from local directory: /root...
# dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-306-5deb1e94bdad> in <module>
# ----> 1 python = python.version()
#
# NameError: name 'python' is not defined
